# %% [markdown]
# <a href="https://colab.research.google.com/github/EDodson04/First-Project-DA/blob/main/Module2Project_Dodson.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('data_analytics_students.csv')

# %%
df.head()
# Out:
#    Age Height Prior Data Experience Favorite Season Book or movie?  \
# 0   28     64                   Yes            Fall           Book
# 1   30     71                   Yes            Fall           Book
# 2   53     68                    No            Fall           Book
# 3   46     66                   Yes          Spring           Book
# 4   29     70                    No            Fall          Movie
#
#   Favorite Hobby                 Fictional Character
# 0        Reading                               Eevee
# 1         coding                                Olaf
# 2        Reading          The Abbot of Redwall Abbey
# 3         Crafts  Myne from Ascendance of a Bookworm
# 4    Photography                     Josephine March

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89 entries, 0 to 88
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Age                    89 non-null     int64
#  1   Height                 89 non-null     object
#  2   Prior Data Experience  89 non-null     object
#  3   Favorite Season        89 non-null     object
#  4   Book or movie?         89 non-null     object
#  5   Favorite Hobby         89 non-null     object
#  6   Fictional Character    89 non-null     object
# dtypes: int64(1), object(6)
# memory usage: 5.0+ KB

# %%
average_age = df['Age'].mean()
print(average_age)
# Out:
# 31.820224719101123

# %%
print(df.iloc[80]['Age'])
# Out:
# 57

# %%
print(df.iloc[24]['Favorite Hobby'])
# Out:
# Songwriting

# %%
print(df.iloc[42]['Fictional Character'])
# Out:
# Batman

# %%
most_common_hobby = df['Favorite Hobby'].value_counts().index[0]
print(most_common_hobby)
# Out:
# Reading

# %%
most_common_fictional_character = df['Fictional Character'].value_counts().index[0]
print(most_common_fictional_character)
# Out:
# Iron Man

# %%
favorite_season = df['Favorite Season'].value_counts().index[0]
print(favorite_season)
# Out:
# Fall

# %%
# Count students with prior experience
num_experienced = df['Prior Data Experience'].eq('Yes').sum()

# Total number of students
total_students = len(df)

# Calculate percentage as a decimal
percent_experienced = round(num_experienced / total_students, 3)

print(percent_experienced)
# Out:
# 0.292

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89 entries, 0 to 88
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Age                    89 non-null     int64
#  1   Height                 89 non-null     object
#  2   Prior Data Experience  89 non-null     object
#  3   Favorite Season        89 non-null     object
#  4   Book or movie?         89 non-null     object
#  5   Favorite Hobby         89 non-null     object
#  6   Fictional Character    89 non-null     object
# dtypes: int64(1), object(6)
# memory usage: 5.0+ KB

# %%
df[0:45]
# Out:
#     Age     Height Prior Data Experience Favorite Season Book or movie?  \
# 0    28         64                   Yes            Fall           Book
# 1    30         71                   Yes            Fall           Book
# 2    53         68                    No            Fall           Book
# 3    46         66                   Yes          Spring           Book
# 4    29         70                    No            Fall          Movie
# 5    20         73                    No          Winter          Movie
# 6    26         78                    No          Winter          Movie
# 7    29         70                    No          Summer          Movie
# 8    24         72                    No          Winter           Book
# 9    26         73                    No          Spring          Movie
# 10   60         74                   Yes            Fall          Movie
# 11   78         77                    No          Spring          Movie
# ...

# %%
df[46:89]
# Out:
#     Age     Height Prior Data Experience Favorite Season Book or movie?  \
# 46   41         71                    No          Spring          Movie
# 47   39         64                    No          Winter          Movie
# 48   23         64                    No            Fall           Book
# 49   28         65                    No          Winter          Movie
# 50   24         63                    No            Fall           Book
# 51   32          5                    No          Summer          Movie
# 52   58         61                   Yes          Spring           Book
# 53   25         71                    No          Spring          Movie
# 54   48         72                    No          Spring          Movie
# 55   20         70                    No          Spring          Movie
# 56   18         68                    No            Fall           Book
# 57   17         67                   Yes          Summer           Book
# ...

# %%
df.loc[20, 'Height'] = 74
df.loc[31, 'Height'] = 69
df.loc[41, 'Height'] = 69
df.loc[51, 'Height'] = 65
df.loc[54, 'Height'] = 72
df.loc[55, 'Height'] = 70
df.loc[58, 'Height'] = 64
df.loc[65, 'Height'] = 64
df.loc[66, 'Height'] = 68
df.loc[70, 'Height'] = 69
df.loc[82, 'Height'] = 64

# %%
df[0:45]
# Out:
#     Age Height Prior Data Experience Favorite Season Book or movie?  \
# 0    28     64                   Yes            Fall           Book
# 1    30     71                   Yes            Fall           Book
# 2    53     68                    No            Fall           Book
# 3    46     66                   Yes          Spring           Book
# 4    29     70                    No            Fall          Movie
# 5    20     73                    No          Winter          Movie
# 6    26     78                    No          Winter          Movie
# 7    29     70                    No          Summer          Movie
# 8    24     72                    No          Winter           Book
# 9    26     73                    No          Spring          Movie
# 10   60     74                   Yes            Fall          Movie
# 11   78     77                    No          Spring          Movie
# 12   60     68                    No            Fall          Movie
# ...

# %%
df[46:89]
# Out:
#     Age Height Prior Data Experience Favorite Season Book or movie?  \
# 46   41     71                    No          Spring          Movie
# 47   39     64                    No          Winter          Movie
# 48   23     64                    No            Fall           Book
# 49   28     65                    No          Winter          Movie
# 50   24     63                    No            Fall           Book
# 51   32     65                    No          Summer          Movie
# 52   58     61                   Yes          Spring           Book
# 53   25     71                    No          Spring          Movie
# 54   48     72                    No          Spring          Movie
# 55   20     70                    No          Spring          Movie
# 56   18     68                    No            Fall           Book
# 57   17     67                   Yes          Summer           Book
# 58   28     64                    No            Fall           Book
# ...

# %%
df.tail(20)
# Out:
#     Age Height Prior Data Experience Favorite Season Book or movie?  \
# 69   26     70                    No            Fall          Movie
# 70   18     69                    No            Fall          Movie
# 71   36     60                   Yes          Winter          Movie
# 72   54     65                    No          Spring          Movie
# 73   32     70                    No          Winter           Book
# 74   46     66                   Yes          Spring           Book
# 75   27     70                    No          Spring          Movie
# 76   18     74                    No            Fall          Movie
# 77   22     70                    No          Summer           Book
# 78   21     69                   Yes          Summer          Movie
# 79   27     73                   Yes          Summer           Book
# 80   57     65                    No            Fall          Movie
# 81   23     67                    No          Summer           Book
# ...

# %%
df_sorted = df.sort_values(by='Age', ascending=False)
df_sorted.head(10)
# Out:
#     Age Height Prior Data Experience Favorite Season Book or movie?  \
# 11   78     77                    No          Spring          Movie
# 10   60     74                   Yes            Fall          Movie
# 12   60     68                    No            Fall          Movie
# 86   58     67                    No            Fall           Book
# 52   58     61                   Yes          Spring           Book
# 80   57     65                    No            Fall          Movie
# 38   56     61                   Yes          Spring          Movie
# 72   54     65                    No          Spring          Movie
# 2    53     68                    No            Fall           Book
# 30   51     68                   Yes          Summer          Movie
#
#                    Favorite Hobby         Fictional Character
# 11                Sniffing babies    The emperor in Star Wars
# 10                         gaming             Sherlock Holmes
# ...

# %%
df_sorted = df.sort_values(by='Age', ascending=False)
df_sorted.tail(10)
# Out:
#     Age Height Prior Data Experience Favorite Season Book or movie?  \
# 5    20     73                    No          Winter          Movie
# 76   18     74                    No            Fall          Movie
# 70   18     69                    No            Fall          Movie
# 82   18     64                    No          Winter           Book
# 56   18     68                    No            Fall           Book
# 41   18   69.1                    No          Winter          Movie
# 26   17     76                    No          Summer          Movie
# 57   17     67                   Yes          Summer           Book
# 88   17     63                    No          Spring          Movie
# 87   14     68                   Yes            Fall           Book
#
#             Favorite Hobby                      Fictional Character
# 5         skate, snowboard           Mahadeva "Highest of all gods"
# 76          Playing guitar  Toothless from How to Train Your Dragon
# ...

# %%
df.to_csv('clean_students_data.csv', index=False)
